# %%
'''
In this project we are trying to find out the churn-rate of Telecom Company.

We use cross tab technique to find compute a simple cross tabulation of multiple factors.


'''

import pandas as pd
import numpy as np
from pandas import DataFrame
from sklearn import preprocessing
import matplotlib.pyplot as plt
import os

# %%
os.chdir('C:\\Desktop\\Github\\Data_Manipulation')

# %%
data = pd.read_csv("Telco-Customer-Churn_Final.csv", sep = ",", header = 0)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data['tenure'].mean()
# Out:
# 32.39954564816129

# %%
data['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.399546
# std        24.662895
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max       172.000000
# Name: tenure, dtype: float64

# %%
data.groupby(['Churn'], as_index=False)['tenure'].mean()
# Out:
#   Churn     tenure
# 0    No  37.569965
# 1   Yes  18.086142

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     6841.000000
# mean        0.162147    32.399546       64.588203
# std         0.368612    24.662895       30.513819
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       34.250000
# 50%         0.000000    29.000000       69.800000
# 75%         0.000000    55.000000       90.200000
# max         1.000000   172.000000      118.750000

# %%
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges      202
# Churn                 0
# dtype: int64

# %%
data.Churn.value_counts()/data.shape[0]
# Out:
# No     0.73463
# Yes    0.26537
# Name: Churn, dtype: float64

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
pd.options.display.float_format = '{:0f}'.format
data.describe()
# Out:
#        SeniorCitizen      tenure  MonthlyCharges
# count    7043.000000 7043.000000     6841.000000
# mean        0.162147   32.399546       64.588203
# std         0.368612   24.662895       30.513819
# min         0.000000    0.000000       18.250000
# 25%         0.000000    9.000000       34.250000
# 50%         0.000000   29.000000       69.800000
# 75%         0.000000   55.000000       90.200000
# max         1.000000  172.000000      118.750000

# %%
summary = data.describe(include='all')
summary.to_csv('summary.csv',sep=',')

# %%
summary.to_csv('summary.csv',sep=',')

# %% [markdown]
# data.loc[(data['tenure']>80),tenure]

# %%
data.loc[(data['tenure']>80)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3890  3886-CERTZ  Female              0     Yes         No     172
# 4610  2889-FPWRM    Male              0     Yes         No     172
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 3890          Yes           Yes     Fiber optic             No          Yes
# 4610          Yes           Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 3890              Yes         Yes         Yes             Yes  One year
# 4610              Yes         Yes         Yes             Yes  One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges Churn
# 3890              Yes           Electronic check      109.250000   Yes
# 4610              Yes  Bank transfer (automatic)      117.800000   Yes

# %%
data['MonthlyCharges'].quantile(0.99)
# Out:
# 114.88000000000002

# %%
data['tenure'].quantile(0.99)
# Out:
# 72.0

# %%
data.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
data.Churn.value_counts()/data.shape[0]
# Out:
# No    0.734630
# Yes   0.265370
# Name: Churn, dtype: float64

# %%
pd.crosstab(data.Churn,data.Dependents,margins=True)/data.shape[0]
# Out:
# Dependents       No      Yes      All
# Churn
# No         0.481329 0.253301 0.734630
# Yes        0.219083 0.046287 0.265370
# All        0.700412 0.299588 1.000000

# %%
pd.crosstab(data.Churn,data.InternetService,margins=True)/data.shape[0]
# Out:
# InternetService      DSL  Fiber optic       No      All
# Churn
# No              0.278574     0.255431 0.200625 0.734630
# Yes             0.065171     0.184154 0.016044 0.265370
# All             0.343746     0.439585 0.216669 1.000000

# %%
pd.crosstab(data.Churn,data.Contract,margins=True)/data.shape[0]
# Out:
# Contract  Month-to-month  One year  Two year      All
# Churn
# No              0.315207  0.185574  0.233849 0.734630
# Yes             0.234985  0.023570  0.006815 0.265370
# All             0.550192  0.209144  0.240664 1.000000

# %%
pd.crosstab(data.Churn,data.PaymentMethod,margins=True)/data.shape[0]
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# Churn
# No                              0.182593                 0.183161
# Yes                             0.036632                 0.032941
# All                             0.219225                 0.216101
#
# PaymentMethod  Electronic check  Mailed check      All
# Churn
# No                     0.183729      0.185148 0.734630
# Yes                    0.152066      0.043731 0.265370
# All                    0.335794      0.228880 1.000000

# %%
data['MonthlyCharges'].unique()
# Out:
# array([29.85, 56.95, 53.85, ..., 63.1 , 44.2 , 78.7 ])

# %%
data['MonthlyCharges']=data['MonthlyCharges'].fillna(data['MonthlyCharges'].mean())

# %%
data['MonthlyCharges'].mean()
# Out:
# 64.58820347902339

# %%
avg=data['tenure'].mean()

# %%
data.loc[(data['tenure']>80),"tenure"] = avg

# %%
data.tenure.describe()
# Out:
# count   7043.000000
# mean      32.359903
# std       24.550396
# min        0.000000
# 25%        9.000000
# 50%       29.000000
# 75%       55.000000
# max       72.000000
# Name: tenure, dtype: float64

# %%
def f(data):
    if data['Dependents'] == "Yes":
        val = 'Yes'
    elif data['Partner'] == "Yes":
        val = 'Yes'
    else:
        val = 'No'
    return val
data['new'] = data.apply(f, axis=1)

# %%
data['new'].head()
# Out:
# 0    Yes
# 1     No
# 2     No
# 3     No
# 4     No
# Name: new, dtype: object

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female              0     Yes         No  1.000000
# 1  5575-GNVDE    Male              0      No         No 34.000000
# 2  3668-QPYBK    Male              0      No         No  2.000000
# 3  7795-CFOCW    Male              0      No         No 45.000000
# 4  9237-HQITU  Female              0      No         No  2.000000
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data['Singles']=np.where(np.logical_and(data['Dependents'] == 'Yes',data['Partner'] == 'Yes'),"Yes","No")

# %%
pd.crosstab(data.Churn,data.Singles,margins=True)/data.shape[0]
# Out:
# Singles       No      Yes      All
# Churn
# No      0.521653 0.212977 0.734630
# Yes     0.230016 0.035354 0.265370
# All     0.751668 0.248332 1.000000

# %%
data['monthup']=np.where(data['Contract']=='Month-to-month',1,0)

# %%
pd.crosstab(data.Churn,data.monthup,margins=True)

# %%
 pd.cut(np.array([0,12,36,80]), labels=["Short", "medium", "long"])

# %%
bins = [0,12,36,80]
labels=["Short", "medium", "long"]
data['Ten'] = pd.cut(data['tenure'], bins,labels=labels)

# %%
data['Ten'].value_counts()
# Out:
# long      2999
# Short     2175
# medium    1856
# Name: Ten, dtype: int64

# %%
data['Short_Contracts']=np.where(np.logical_and(data['Contract'] == 'Month-to-month',data['Ten'] == 'Short'),"Yes","No")

# %%
pd.crosstab(data.Churn,data.Short_Contracts,margins=True)/data.shape[0]
# Out:
# Short_Contracts       No      Yes      All
# Churn
# No              0.596905 0.137725 0.734630
# Yes             0.119977 0.145393 0.265370
# All             0.716882 0.283118 1.000000

# %%
data['paymeth']=np.where(data['PaymentMethod']=='Electronic check',1,0)

# %%
data['paymeth']=np.where(data['PaymentMethod']=='Electronic check',1,0)

# %%
data1=data[['PaymentMethod','Churn']]

# %%
data1.head()
# Out:
#                PaymentMethod Churn
# 0           Electronic check    No
# 1               Mailed check    No
# 2               Mailed check   Yes
# 3  Bank transfer (automatic)    No
# 4           Electronic check   Yes

# %%
data['new2']=np.where(np.logical_and(data['PaymentMethod'] == 'Bank transfer (automatic)',data['PaymentMethod'] == 'Credit card (automatic)'),1,0)

# %%
data2 = data.loc[data['Churn'] == 'Yes']

# %%
data2.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... TechSupport StreamingTV  \
# 2             No             DSL            Yes  ...          No          No
# 4             No     Fiber optic             No  ...          No          No
# 5            Yes     Fiber optic             No  ...          No         Yes
# 8            Yes     Fiber optic             No  ...         Yes         Yes
# 13           Yes     Fiber optic             No  ...          No         Yes
#
# ...

# %%
pd.crosstab(data2.new2,data.paymeth,margins=True)/data2.shape[0]
# Out:
# paymeth         0         1  All
# new2
# 0        0.426966  0.573034  1.0
# All      0.426966  0.573034  1.0

# %%
data['combi']=np.where(np.logical_and(,,,),1,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-131f7907bac2> in <module>
# ----> 1 data['combi']=np.where(np.logical_and(data['OnlineSecurity'] == 'No',data['OnlineBackup'] == 'No',data['DeviceProtection'] == 'No',data['TechSupport'] == 'No'),1,0)
#
# ValueError: invalid number of arguments

# %%
def conditions(s):
    if (data['OnlineSecurity'] == 'No' & (data['OnlineBackup'] == 'No') & (data['DeviceProtection'] == 'No') & (data['TechSupport'] == 'No') :
        return 1
    else:
        return 0
data['Comb'] = data.apply(conditions, axis=1)
# Out:
#   File "<ipython-input-29-168552a8fa77>", line 2
#     if (data['OnlineSecurity'] == 'No' & (data['OnlineBackup'] == 'No') & (data['DeviceProtection'] == 'No') & (data['TechSupport'] == 'No') :
#                                                                                                                                              ^
# SyntaxError: invalid syntax

# %%
data["new3"]=data['OnlineSecurity']+data["OnlineBackup"]+data["DeviceProtection"]+data["TechSupport"]

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female              0     Yes         No  1.000000
# 1  5575-GNVDE    Male              0      No         No 34.000000
# 2  3668-QPYBK    Male              0      No         No  2.000000
# 3  7795-CFOCW    Male              0      No         No 45.000000
# 4  9237-HQITU  Female              0      No         No  2.000000
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
data['new4']=np.where(data['new3']=='NoNoNoNo',1,0)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents    tenure  \
# 0  7590-VHVEG  Female              0     Yes         No  1.000000
# 1  5575-GNVDE    Male              0      No         No 34.000000
# 2  3668-QPYBK    Male              0      No         No  2.000000
# 3  7795-CFOCW    Male              0      No         No 45.000000
# 4  9237-HQITU  Female              0      No         No  2.000000
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#          Contract PaperlessBilling              PaymentMethod MonthlyCharges  \
# ...

# %%
pd.crosstab(data2.new2,data.new4,margins=True)/data2.shape[0]
# Out:
# new4        0        1      All
# new2
# 0    0.615837 0.384163 1.000000
# All  0.615837 0.384163 1.000000
